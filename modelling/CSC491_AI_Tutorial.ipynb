# %% [markdown]
# # 1. Introduction

# %% [markdown]
# The purpose of this tutorial is to provide you with an introduction to some of the commonly used machine learning techniques. Given that the focus of the course this semester is with SOCAN, I've chosen to use a Spotify Music dataset. The tutorial will go over data preprocessing and modelling techniques. The corresponding presentations will go through APIs for NLP and audio processing that may be useful in prototyping your ideas.

# %% [markdown]
# # 2. Import Packages

# %%
import numpy as np
import pandas as pd # this library is used for data processing
import seaborn as sns # used for data visualization

from matplotlib import pyplot as plt
# %matplotlib inline
sns.set_style("whitegrid")

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 3. Loading Dataset

# %% [markdown]
# The first step in any machine learning project is to load your dataset. We use the pandas library to do this as it provides us with dataframe objects that handle large amounts of data well.

# %%
spotify_df = pd.read_csv('../data/SpotifyFeatures.csv')
spotify_df.head()
# Out:
#    genre      artist_name                                         track_name  \
# 0  Opera   Giuseppe Verdi  Stiffelio, Act III: Ei fugge! … Lina, pensai c...
# 1  Opera  Giacomo Puccini  Madama Butterfly / Act 1: ... E soffitto e pareti
# 2  Opera  Giacomo Puccini      Turandot / Act 2: Gloria, gloria, o vincitore
# 3  Opera   Giuseppe Verdi       Rigoletto, Act IV: Venti scudi hai tu detto?
# 4  Opera   Giuseppe Verdi           Don Carlo / Act 4: "Ella giammai m'amò!"
#
#                  track_id  popularity  acousticness  danceability  \
# 0  7EsKYeHtTc4H4xWiTqSVZA          21         0.986         0.313
# 1  7MfmRBvqaW0I6UTxXnad8p          18         0.972         0.360
# 2  7pBo1GDhIysyUMFXiDVoON          10         0.935         0.168
# 3  02mvYZX5aKNzdqEo6jF20m          17         0.961         0.250
# 4  03TW0jwGMGhUabAjOpB1T9          19         0.985         0.142
#
#    duration_ms   energy  instrumentalness key  liveness  loudness   mode  \
# 0       490867  0.23100          0.000431  C#    0.0964   -14.287  Major
# 1       176797  0.20100          0.028000  D#    0.1330   -19.794  Major
# 2       266184  0.47000          0.020400   C    0.3630    -8.415  Major
# 3       288573  0.00605          0.000000   D    0.1200   -33.440  Major
# 4       629760  0.05800          0.146000   D    0.0969   -23.625  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0547   86.001            4/4   0.0886
# 1       0.0581  131.798            4/4   0.3690
# 2       0.0383   75.126            3/4   0.0696
# 3       0.0480   76.493            4/4   0.0380
# 4       0.0493  172.935            4/4   0.0382

# %% [markdown]
# As we can see above there are a number of attributes about each song that could be interesting features for us to look at and use to answer our question of whether a song is popular or not.

# %% [markdown]
# # 4. Dataset Statistics

# %% [markdown]
# Often times it is important to understand the summary statistics of your data to get a better sense of what type of preprocessing you might need. Here we get a sense for how many examples there are for each feature, the mean, standard deviation, the minimum value and maximum value.

# %%
spotify_df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  228159.000000  228159.000000  228159.000000  2.281590e+05
# mean       44.209130       0.351200       0.554198  2.366092e+05
# std        17.276599       0.351385       0.183949  1.166787e+05
# min         0.000000       0.000001       0.056900  1.550900e+04
# 25%        33.000000       0.030900       0.437000  1.862530e+05
# 50%        47.000000       0.205000       0.570000  2.211730e+05
# 75%        57.000000       0.689000       0.690000  2.648400e+05
# max       100.000000       0.996000       0.987000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  228159.000000     228159.000000  228159.000000  228159.000000
# mean        0.580967          0.137310       0.214638      -9.354658
# std         0.260577          0.292447       0.196977       5.940994
# min         0.000020          0.000000       0.009670     -52.457000
# 25%         0.405000          0.000000       0.097700     -11.287000
# 50%         0.618000          0.000037       0.128000      -7.515000
# 75%         0.793000          0.023400       0.263000      -5.415000
# max         0.999000          0.999000       1.000000       1.585000
#
#          speechiness          tempo        valence
# count  228159.000000  228159.000000  228159.000000
# mean        0.122442     117.423062       0.444795
# std         0.186264      30.712458       0.255397
# min         0.022200      30.379000       0.000000
# 25%         0.036800      92.734000       0.232000
# 50%         0.050600     115.347000       0.430000
# 75%         0.109000     138.887000       0.643000
# max         0.967000     239.848000       1.000000

# %% [markdown]
# # 5. Data Preprocessing

# %% [markdown]
# This is a crucial part of any machine learning project because these preprocessing steps can drastically improve your model's performance. We also need to be sure that we get rid of errors in the data that may cause issues such as null values.

# %% [markdown]
# ## a. Cleaning Null Values

# %%
pd.isnull(spotify_df).sum()
# Out:
# genre               0
# artist_name         0
# track_name          0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %% [markdown]
# Based on our check, there are no null values in the data thus there are no further steps needed to deal with null values!

# %% [markdown]
# ## b. Dealing with Categorical Variables

# %% [markdown]
# Categorical type data is commonly found but we need to be able to provide our models with only numerical representations of our data. Thus for categorical variables we simply change the categories from 1 to number of categories.

# %% [markdown]
# ### 1. Key

# %%
list_of_keys = spotify_df['key'].unique()
for i in range(len(list_of_keys)):
    spotify_df.loc[spotify_df['key'] == list_of_keys[i], "key"] = i
spotify_df.sample(5)
# Out:
#             genre     artist_name                    track_name  \
# 99577         Rap  Kendrick Lamar                       Compton
# 50797  Electronic          Bonobo  If You Stayed Over - Reprise
# 47332  Electronic             Vök                   Night & Day
# 17126       Dance            Dido                       Friends
# 12879         Pop      Jason Mraz                     I'm Yours
#
#                      track_id  popularity  acousticness  danceability  \
# 99577  1wf4LnpdAhLaoI2WwYDKAE          54        0.0815         0.342
# 50797  5JrslPPXLFnUJzq85P6qTv          33        0.9120         0.352
# 47332  6UkBBvlkNhbdFBz6i3KQmC          34        0.0140         0.717
# 17126  7ohyW5BmiG0jKcvw31fhHH          37        0.6700         0.815
# 12879  1EzrEOXmMH3G43AXT1y7pA          85        0.5950         0.686
#
#        duration_ms  energy  instrumentalness  key  liveness  loudness   mode  \
# 99577       248093   0.907          0.000000    0    0.3830    -4.432  Minor
# 50797       104411   0.526          0.967000    9    0.0680   -14.956  Minor
# 47332       195484   0.582          0.000609    8    0.1480    -8.121  Major
# 17126       203933   0.396          0.041800    5    0.0999   -10.981  Minor
# 12879       242187   0.457          0.000000    6    0.1050    -8.322  Major
#
#        speechiness    tempo time_signature  valence
# 99577       0.4150  170.380            4/4   0.2250
# 50797       0.0482  170.001            4/4   0.0519
# 47332       0.0788   93.988            4/4   0.5850
# 17126       0.0332  123.007            4/4   0.4500
# 12879       0.0468  150.953            4/4   0.7180

# %% [markdown]
# ### 2. Mode (Binary Variable)

# %%
spotify_df.loc[spotify_df["mode"] == 'Major', "mode"] = 1
spotify_df.loc[spotify_df["mode"] == 'Minor', "mode"] = 0
spotify_df.sample(5)
# Out:
#                    genre    artist_name  \
# 94735   Children’s Music      Grouplove
# 209813             Movie     Mel Gibson
# 62040                R&B         Shoffy
# 148118             Indie  Knox Hamilton
# 21306        Alternative       Gorillaz
#
#                                                track_name  \
# 94735                                 Standing in The Sun
# 209813                          Funny How Time Slips Away
# 62040                                            Movin On
# 148118                                Pretty Way to Fight
# 21306   The Apprentice (feat. Rag'n'Bone Man, Zebra Ka...
#
#                       track_id  popularity  acousticness  danceability  \
# 94735   6kCHznMiHnRaNDHXwHmrrV          50       0.00317         0.475
# 209813  1OTt0jwBX5riJ0MnvRLcov           1       0.17900         0.381
# 62040   64TUmDi8kUUCF816GhdRXX          58       0.48800         0.807
# 148118  6FI9HEkxiYljt06KHdmpKE          46       0.00725         0.525
# 21306   67fRHOlaYQQFG67D9DkdnW          56       0.18200         0.446
#
#         duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 94735        255893   0.594          0.000007    6    0.0752    -7.331     1
# 209813       262000   0.634          0.000350   11    0.1420    -7.600     1
# 62040        211636   0.339          0.016500    8    0.1070   -12.958     1
# 148118       203667   0.893          0.057600    0    0.2190    -4.776     1
# 21306        234933   0.648          0.000011    6    0.3480    -6.773     0
#
#         speechiness    tempo time_signature  valence
# 94735        0.0292  180.277            4/4    0.626
# 209813       0.0286   69.323            4/4    0.548
# 62040        0.0550  110.004            4/4    0.131
# 148118       0.0665  153.996            4/4    0.336
# 21306        0.3000   86.021            4/4    0.696

# %% [markdown]
# ### 3. Time Signature

# %%
list_of_time_signatures = spotify_df['time_signature'].unique()
for i in range(len(list_of_time_signatures)):
    spotify_df.loc[spotify_df['time_signature'] == list_of_time_signatures[i], 'time_signature'] = i
spotify_df.sample(5)
# Out:
#               genre            artist_name  \
# 115118    Classical  Johann Sebastian Bach
# 9526    Alternative      Portugal. The Man
# 108207      Hip-Hop              Too $hort
# 77308          Folk          Patty Griffin
# 192163         Soul             Eric Benét
#
#                                                track_name  \
# 115118  St. Matthew Passion, BWV 244, Pt. 1: No. 10, I...
# 9526                        Feel It Still - Medasin Remix
# 108207                                   Blow the Whistle
# 77308                       Up To The Mountain (MLK Song)
# 192163                                         Femininity
#
#                       track_id  popularity  acousticness  danceability  \
# 115118  5dc71dIr7dIxy5LOe9J35R           0        0.9850         0.206
# 9526    4m6ObZmZ7wnyrKtmLvlyVE          63        0.5530         0.568
# 108207  2lMg3lCMOGistaWBNGjuT3          62        0.0042         0.907
# 77308   2W0n4u0ySQpkLVeg6rOOr1          42        0.9400         0.298
# 192163  1NyMdeeVDYizUcXHConsq6          39        0.1020         0.677
#
#         duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 115118        58587  0.0642          0.958000    8    0.1170   -26.193     1
# 9526         194434  0.4630          0.001140    9    0.0858   -10.622     1
# 108207       163133  0.6250          0.000000    0    0.1510    -5.557     1
# 77308        248867  0.2040          0.000106    6    0.1150    -7.242     1
# 192163       288600  0.6300          0.000000    5    0.0554    -4.778     1
#
#         speechiness    tempo  time_signature  valence
# 115118       0.0397   64.397               0    0.251
# 9526         0.2620  157.686               0    0.148
# 108207       0.1980   99.918               0    0.605
# 77308        0.0323   84.126               2    0.218
# 192163       0.0500   72.954               0    0.625

# %% [markdown]
# ### 4. Popularity (Label)

# %%
spotify_df['popularity'] = np.where(spotify_df['popularity'] >= 57, 1, 0)

# %% [markdown]
# # 6. Training Models

# %% [markdown]
# Now that we have preprocess our data, we are ready to train and evaluate models. First thing we need to do is to split our dataset into a training set and a test set. The training set is used to train the algorithm and the test set is used to evaluate its performance on unseen data. Splitting and the models themselves are often done using the scikit-learn library.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ## Dataset Split

# %%
features = ["acousticness", "danceability", "duration_ms", "energy", "instrumentalness", "key", "liveness",
            "mode", "speechiness", "tempo", "time_signature", "valence"]

# %%
training_df = spotify_df.sample(frac = 0.8, random_state= 420)
X_train = training_df[features]
y_train = training_df['popularity']
X_test = training_df.drop(training_df.index)[features]

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2, random_state = 420)

# %% [markdown]
# ## Logistic Regression

# %%
LR_Model = LogisticRegression()
LR_Model.fit(X_train, y_train)
LR_Predict = LR_Model.predict(X_valid)
LR_Accuracy = accuracy_score(y_valid, LR_Predict)
print("Accuracy: " + str(LR_Accuracy))

LR_AUC = roc_auc_score(y_valid, LR_Predict) 
print("AUC: " + str(LR_AUC))
# Out:
# Accuracy: 0.7497945543198379
# AUC: 0.5

# %% [markdown]
# ## Random Forest

# %%
RFC_Model = RandomForestClassifier()
RFC_Model.fit(X_train, y_train)
RFC_Predict = RFC_Model.predict(X_valid)
RFC_Accuracy = accuracy_score(y_valid, RFC_Predict)
print("Accuracy: " + str(RFC_Accuracy))

RFC_AUC = roc_auc_score(y_valid, RFC_Predict) 
print("AUC: " + str(RFC_AUC))
# Out:
# Accuracy: 0.9348874157672711
# AUC: 0.879036656108296

# %% [markdown]
# ## Neural Network

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(12, )),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='Adam',
             loss='binary_crossentropy',
             metrics=['Accuracy', 'AUC'])

model.fit(X_train, y_train, epochs=10)
# Out:
# Train on 146021 samples
# Epoch 1/10
# 146021/146021 [==============================] - 6s 38us/sample - loss: 189.3717 - Accuracy: 0.5709 - AUC: 0.4989
# Epoch 2/10
# 146021/146021 [==============================] - 5s 34us/sample - loss: 146.2181 - Accuracy: 0.5533 - AUC: 0.4999
# Epoch 3/10
# 146021/146021 [==============================] - 5s 34us/sample - loss: 123.3467 - Accuracy: 0.5478 - AUC: 0.5019
# Epoch 4/10
# 146021/146021 [==============================] - 6s 38us/sample - loss: 122.6797 - Accuracy: 0.5450 - AUC: 0.5022
# Epoch 5/10
# 146021/146021 [==============================] - 6s 40us/sample - loss: 112.7771 - Accuracy: 0.5434 - AUC: 0.5073
# Epoch 6/10
# 146021/146021 [==============================] - 6s 40us/sample - loss: 103.7473 - Accuracy: 0.5369 - AUC: 0.5081
# Epoch 7/10
# 146021/146021 [==============================] - 5s 37us/sample - loss: 99.3363 - Accuracy: 0.5323 - AUC: 0.5087
# Epoch 8/10
# 146021/146021 [==============================] - 5s 36us/sample - loss: 82.3370 - Accuracy: 0.5152 - AUC: 0.5149
# Epoch 9/10
# 146021/146021 [==============================] - 5s 36us/sample - loss: 82.5424 - Accuracy: 0.5201 - AUC: 0.5105
# Epoch 10/10
# 146021/146021 [==============================] - 5s 35us/sample - loss: 72.4423 - Accuracy: 0.4924 - AUC: 0.5155

# %% [markdown]
# # Conclusion

# %% [markdown]
# Now you've gone through the process of a machine learning model applied to Spotify data. It is important to keep these concepts of data preprocessing and model selection when determining the best way to solve your problems. S
